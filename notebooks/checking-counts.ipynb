# %%
import pathlib
import scanpy as sc
import anndata as ad
from tqdm import tqdm

# %%
adata = sc.read_h5ad("/oak/stanford/projects/kibr/Reorganizing/Projects/James/lipid-droplet-single-cell-pipeline/data/processed/lipid_droplet_shape_clusters/17APR2025.h5ad")
# Out:
# /oak/stanford/projects/kibr/Reorganizing/Projects/James/lipid-droplet-pipeline/.venv/lib/python3.12/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata[adata.obs["cell_type"].eq("Microglia-PVM")].write_h5ad("microglia-pvm.h5ad")
